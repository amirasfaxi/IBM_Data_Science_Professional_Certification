# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sfaxi Amira**
#
#  Data scientist

# %% [markdown]
# *I am interested in data science because i love working with data and get information from it*

# %% [markdown]
# ### The below should print the nomber of days in a week

# %%
print("The number of  days in a week is 7 " )
# Out:
# The number of  days in a week is 7

# %% [markdown]
# ### Horizontal rule
#
# Hello everybody...
#
# ---
#
# How are you
#
# ***
#
# Thank you for your help
#
# ___
#
# this is  my work
#
# ### Lists
#
# 1. list1
# 2. List2
# - list2-1
#
# ### Blockquotes
#
# > One
# > two
#
#
#  Quote break.
#
#
# > three
